# %% [markdown]
# <a href="https://colab.research.google.com/github/basartimucin/MPA-MLF/blob/main/Week_6_Lab_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # MPA-MLF, Lab 7 - Convolutional Neural Network

# %% [markdown]
# ## Exercise - Hand-written digits recognition

# %% [markdown]
# Create CNN which will process and recognize handwritten digits. For this purposes please use the MNIST database (Modified National Institute of Standards and Technology database) which is a large database of handwritten digits that is commonly used for training various image processing systems.
#
# The datasample of the MNIST datasets can be see in the following picture

# %% [markdown]
# ![mnist_data_sample.png](attachment:eb3e0d6a-ccb0-499d-9847-ecbc554dbce0.png)

# %% [markdown]
# ### Task description

# %% [markdown]
# In the terms of machine learning, the Hand-written digits recognition can be threated as a multi-class classification problem. This is very important knowledge to structure our model in the correct way (Especially the output-layer, including the number of neurons and activations function and the overall loss function and classification metrics)

# %% [markdown]
# ### 0. Import libraries

# %% [markdown]
# Import the all necessary libraries, you can get inspired by the previous exercises. You can improst the libraries gradually, when do you progressing with the task

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.layers import Conv2D , MaxPooling2D, Dense, Dropout, Flatten
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

###################################
# Write your own code here #



###################################
font = {'weight' : 'bold',
        'size'   : 12}

matplotlib.rc('font', **font)

# %% [markdown]
# ### 1. Dataset

# %% [markdown]
# #### 1.1 Load Dataset

# %% [markdown]
# You can load the dataset using the following code

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# #### 1.2 Dataset examination

# %% [markdown]
# Using the following code, display random images,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels = y_data[selected_ind]
  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img, cmap="gray")

  for id_label, label in enumerate(selected_labels):
    plt.text(14 + 28*id_label, 28*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %% [markdown]
# Examine the dataset. Answer for yourself the following questions:
#
# - What kind of data occurs in our dataset?
# - How many data samples do we have in train and test datasets?
# - How many colour channels does the input variable have?
# - What is the size of the input images?
# - What is the necessary preprocessing of the input data X?
# - How many classes do we have in target varoable?
# - What is the necessary preprocessing of target variable y?

# %% [markdown]
# #### 1.3 Dataset preprocessing

# %% [markdown]
# Perform the necessary data preprocessing. The best way to preprocess the data would be one hot encoding for the target variable and normalization for the input variable (using min-max or z-score normalization)

# %%
###################################
# Write your own code here #
X_train_scaled = X_train.astype('float32') / 255.0
X_test_scaled = X_test.astype('float32') / 255.0

y_train_encoded = to_categorical(y_train, num_classes=10)
y_test_encoded = to_categorical(y_test, num_classes=10)

###################################

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# In this section, your task will be to define the model architecture. The intial structure can be defined as follows:
#
# Input_layer -> Convolutional_layer(kernel_size=(3,3), no_channels=32) -> Maxpooling_layer(kernel_size=(2, 2)) -> Flatten_layer -> Dense_layer (num_classes)

# %% [markdown]
# #### 2.1 Define the model structure

# %%
model = Sequential()
###################################
# Write your own code here #
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(64,(5,5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(4,4)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))



###################################

# %% [markdown]
# #### 2.2 Compile the model

# %% [markdown]
# Build the model, use the relevant metrics, optimizer and loss function. While choosing the metrics and loss function, consider fact that we are are trying to solve the multiclass classification problem

# %%
loss = keras.losses.categorical_crossentropy
optimizer = keras.optimizers.Adadelta()
metrics = ['accuracy']
learning_rate = 0.0001
optimizer = Adam(learning_rate = learning_rate)

###################################
# Write your own code here #
model.compile(loss = loss, optimizer = optimizer,metrics = metrics)



###################################
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        51264
#
#  max_pooling2d_2 (MaxPoolin  (None, 11, 11, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 9, 9, 128)         73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 130570 (510.04 KB)
# Trainable params: 130570 (510.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %% [markdown]
# train your model, define the relevant hyperparameters (no. epochs, batch_size), use 20p of the training data for validation

# %%
###################################
# Write your own code here #
history = model.fit(X_train_scaled, y_train_encoded, epochs=20, batch_size=256,
                    validation_split=0.2, verbose=1)


###################################
# Out:
# Epoch 1/20
# 188/188 [==============================] - 6s 20ms/step - loss: 1.2818 - accuracy: 0.7464 - val_loss: 0.2969 - val_accuracy: 0.9294
# Epoch 2/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2189 - accuracy: 0.9408 - val_loss: 0.1523 - val_accuracy: 0.9564
# Epoch 3/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1407 - accuracy: 0.9594 - val_loss: 0.1119 - val_accuracy: 0.9674
# Epoch 4/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1116 - accuracy: 0.9673 - val_loss: 0.0998 - val_accuracy: 0.9707
# Epoch 5/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0933 - accuracy: 0.9726 - val_loss: 0.0801 - val_accuracy: 0.9769
# Epoch 6/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0810 - accuracy: 0.9757 - val_loss: 0.0742 - val_accuracy: 0.9788
# Epoch 7/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0740 - accuracy: 0.9776 - val_loss: 0.0691 - val_accuracy: 0.9797
# Epoch 8/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0662 - accuracy: 0.9796 - val_loss: 0.0737 - val_accuracy: 0.9785
# Epoch 9/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0606 - accuracy: 0.9815 - val_loss: 0.0611 - val_accuracy: 0.9812
# Epoch 10/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0573 - accuracy: 0.9824 - val_loss: 0.0597 - val_accuracy: 0.9826
# Epoch 11/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0526 - accuracy: 0.9841 - val_loss: 0.0590 - val_accuracy: 0.9815
# Epoch 12/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0507 - accuracy: 0.9845 - val_loss: 0.0546 - val_accuracy: 0.9847
# Epoch 13/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0474 - accuracy: 0.9854 - val_loss: 0.0578 - val_accuracy: 0.9828
# Epoch 14/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0449 - accuracy: 0.9862 - val_loss: 0.0524 - val_accuracy: 0.9837
# Epoch 15/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0424 - accuracy: 0.9866 - val_loss: 0.0497 - val_accuracy: 0.9847
# Epoch 16/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 0.0499 - val_accuracy: 0.9852
# Epoch 17/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.0467 - val_accuracy: 0.9864
# Epoch 18/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0366 - accuracy: 0.9886 - val_loss: 0.0478 - val_accuracy: 0.9855
# Epoch 19/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.0349 - accuracy: 0.9893 - val_loss: 0.0482 - val_accuracy: 0.9862
# Epoch 20/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0334 - accuracy: 0.9897 - val_loss: 0.0454 - val_accuracy: 0.9868

# %% [markdown]
# #### 3.1 Model Evaluation on validation data

# %% [markdown]
# Plot the development of the training and validation loss, and training and validation metrics.

# %%
###################################
# Write your own code here #
plt.figure()
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()



###################################

# %% [markdown]
# ### 4. Model evaluation

# %% [markdown]
# Evaluate the model on the testing dataset using the relevant metrics. Use the confusion metrics as the one of the metrics.

# %%
###################################
# Write your own code here #
score = model.evaluate(X_test_scaled, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')


###################################
# Out:
# Test loss: 0.04012759029865265
# Test accuracy: 98.7999975681305 %

# %% [markdown]
# ### 5. Hyperparameter tunning and regularization techniques

# %% [markdown]
# When your code is ready and fully functional, try several changes in the hyperparameters and see how they influence the testing metrics. Try changes in the network structure. You can also try adding regularization techniques such as L1, L2, and Dropout. Based on the development of training and validation loss, try to identify overfitting and avoid it

# %%
y_prediction = model.predict(X_test_scaled)
y_prediction = np.argmax (y_prediction, axis = 1)
y_test=np.argmax(y_test_encoded, axis=1)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction , normalize='pred')
result= np.around(result, 3)
print(result)
fig, ax = plt.subplots(figsize=(14,6))
sns.heatmap(result, annot=True)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# [[0.987 0.    0.003 0.    0.001 0.    0.003 0.003 0.    0.   ]
#  [0.    0.994 0.001 0.002 0.002 0.002 0.001 0.002 0.    0.   ]
#  [0.002 0.001 0.981 0.    0.    0.    0.001 0.003 0.    0.   ]
#  [0.    0.    0.003 0.986 0.    0.003 0.    0.001 0.001 0.   ]
#  [0.    0.    0.002 0.    0.987 0.    0.001 0.003 0.    0.006]
#  [0.002 0.    0.    0.005 0.    0.984 0.001 0.001 0.001 0.   ]
#  [0.005 0.003 0.001 0.001 0.003 0.003 0.993 0.    0.001 0.   ]
#  [0.    0.002 0.008 0.001 0.    0.001 0.    0.982 0.001 0.   ]
#  [0.001 0.    0.002 0.004 0.002 0.002 0.    0.002 0.994 0.001]
#  [0.003 0.001 0.    0.001 0.005 0.003 0.    0.004 0.002 0.993]]
# <Axes: >
